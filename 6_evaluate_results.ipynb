# %%
import json
import numpy as np

# %%
labels = {'nose':0,
         'sternum':1,
         'Rshoulder':2,
         'Relbow':3,
         'Rwrist':4,
         'Rhip':5,
         'Rknee':6,
         'Rankle':7,
         'Reye':8,
         'Rear':9,
         'Lshoulder':10,
         'Lelbow':11,
         'Lwrist':12,
         'Lhip':13,
         'Lknee':14,
         'Lankle':15,
         'Leye':16,
         'Lear':17}

val_name_list ={'left_Explorer_HD720_SN15385_19-36-03.png',
               'left_Explorer_HD720_SN15385_19-35-42.png',
               'left_Explorer_HD720_SN15385_19-34-44.png',
               'left_Explorer_HD720_SN15385_19-34-37.png',
               'left_Explorer_HD720_SN15385_19-34-18.png',
               'left_Explorer_HD720_SN15385_19-34-00.png',
               'left_Explorer_HD720_SN15385_19-32-20.png',
               'left_Explorer_HD720_SN15385_19-32-12.png',
               'left_Explorer_HD720_SN15385_19-31-20.png',
               'left_Explorer_HD720_SN15385_19-30-22.png'}

val_flag = 0
sigmas = np.array([.26, 1, .79, .72, .62, 1.07, .87, .89, .25, .35, .79, .72, .62, 1.07, .87, .89, .25, .35])/10.0
variances = (sigmas ** 2)*2

# %%
def read_from_gt_dict(gt_dict):
    """
    This function implements reading groundtruth json dict and outputs keypoints and square area
    param: ground truth dict generated by labelme
    """
    res_dict = {}
    
    # recognize how many people in the picture
    flags = gt_dict['flags']
    if flags['1']:
        num = 1
        res_dict['person1'] = {'kpt': np.zeros((2,18)), 'S': 0}
    elif flags['2']:
        num = 2
        res_dict['person1'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person2'] = {'kpt': np.zeros((2,18)), 'S': 0}
    elif flags['3']:
        num = 3
        res_dict['person1'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person2'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person3'] = {'kpt': np.zeros((2,18)), 'S': 0}
    elif flags['4']:
        num = 4
        res_dict['person1'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person2'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person3'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person4'] = {'kpt': np.zeros((2,18)), 'S': 0}
    elif flags['5']:
        num = 5
        res_dict['person1'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person2'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person3'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person4'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person5'] = {'kpt': np.zeros((2,18)), 'S': 0}
    elif flags['6']:
        num = 6
        res_dict['person1'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person2'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person3'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person4'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person5'] = {'kpt': np.zeros((2,18)), 'S': 0}
        res_dict['person6'] = {'kpt': np.zeros((2,18)), 'S': 0}
    else:
        raise ValueError("Wrong flag")
    
    
    for kpt in gt_dict['shapes']:
        name = kpt['label']
        value = kpt['points']
        person_id = 'person' + str(kpt['group_id'])
        
        if name == 'bbox':
            res_dict[person_id]['S'] = abs((value[0][0] - value[1][0])*(value[0][1] - value[1][1]))
        else:
            idx = labels[name]
            res_dict[person_id]['kpt'][:,idx] = value[0]
    return res_dict

# %%
def read_from_pt_dict(pt_dict):
    """
    This function implements reading prediction json dict and outputs keypoints in ndarray format
    param: prediction dict generated by postprocess
    """
    res_dict = {}
    
    for key in pt_dict:
        res_dict[key] = np.zeros((2,18))
        for name in pt_dict[key]:
            idx = labels[name]
            value = pt_dict[key][name]
            res_dict[key][:,idx] = [value[1], value[0]]
    
    return res_dict

# %%
def evaluate_oks(pt_dict, gt_dict):
    gt_kpts = []
    gt_area = []
    for person_id in gt_dict:
        gt_kpts.append(gt_dict[person_id]['kpt'])
        gt_area.append(gt_dict[person_id]['S'])
    
    pt_kpts = []
    for person_id in pt_dict:
        pt_kpts.append(pt_dict[person_id])
    
    res_oks = []
    for person_id in range(len(gt_kpts)):
        gt_kpt = gt_kpts[person_id]
        area = gt_area[person_id]
        best_oks = 0
        for pt_kpt in pt_kpts:
            oks = compute_oks(pt_kpt, gt_kpt, area)
            if oks > best_oks:
                best_oks = oks
        
        res_oks.append(best_oks)
            
    return res_oks

# %%
def compute_oks(pt_kpt, gt_kpt, area):
    gt_mask = gt_kpt!=0
    
    gt_x = gt_kpt[0,:]
    pt_x = pt_kpt[0,:]
    dx = gt_x - pt_x
    
    gt_y = gt_kpt[1,:]
    pt_y = pt_kpt[1,:]
    dy = gt_y - pt_y
    
    e = (dx**2 + dy**2) /variances/ (area+np.spacing(1)) / 2
    oks = np.exp(-e)
    oks = oks[np.nonzero(gt_mask[0,:])]
    
    return np.sum(oks) / oks.shape[0]

# %%
def evaluate_model(pt_json, gt_dir):
    
    with open(pt_json, "r") as f:
        pt_dicts = json.loads(json.load(f))

    n = 1
    oks_all = []
    for img_name in pt_dicts.keys():
        
        if (img_name not in val_name_list) and val_flag:
            continue
            
        print('Processing img.' ,n ,' :', img_name)
        pt_kpts = read_from_pt_dict(pt_dicts[img_name])

        json_name = img_name[:-3] + 'json'
        json_file = gt_dir + json_name
        with open(json_file, "r") as f:
            gt_dict = json.load(f)

        gt_kpts = read_from_gt_dict(gt_dict)

        oks = evaluate_oks(pt_kpts, gt_kpts)
        n += 1

        for each in oks:
            if each < 0.5:
                print(each)
            oks_all.append(each)

    oks_all = np.array(oks_all)
    AP_50 = np.sum(oks_all >= 0.5)/len(oks_all)
    AP_75 = np.sum(oks_all >= 0.75)/len(oks_all)

    T = np.arange(0.5, 1, 0.05)
    mAP = 0
    for t in T:
        temp = np.sum(oks_all >= t)/len(oks_all)
        mAP += temp

    mAP /= T.shape
    mAP
    
    return AP_50, AP_75, mAP

# %%
def compare_result(pt_json1, pt_json2, gt_dir):
    with open(pt_json1, "r") as f:
        pt_dicts1 = json.loads(json.load(f))
    
    with open(pt_json2, "r") as f:
        pt_dicts2 = json.loads(json.load(f))

    n = 1
    oks_all = []
        
    for img_name in pt_dicts1.keys():
            
        pt_kpts1 = read_from_pt_dict(pt_dicts1[img_name])
        pt_kpts2 = read_from_pt_dict(pt_dicts2[img_name])

        json_name = img_name[:-3] + 'json'
        json_file = gt_dir + json_name
        with open(json_file, "r") as f:
            gt_dict = json.load(f)

        gt_kpts = read_from_gt_dict(gt_dict)

        oks1 = evaluate_oks(pt_kpts1, gt_kpts)
        oks2 = evaluate_oks(pt_kpts2, gt_kpts)
        n += 1
        
        for i in range(len(oks1)):
            oks1_single= oks1[i]
            oks2_single= oks2[i]
            if abs(oks1_single - oks2_single) >= 0.3:
                print(img_name)
                print('oks1:', oks1_single)
                print('oks2:', oks2_single)

    return 0

# %%
AP_50, AP_75, mAP = evaluate_model("./results_full/mobilenet_model_COCO+RGB_extra//NMS_v2/record.json", './self_dataset/labelme/gt_json_train/')

print("AP_50: ", AP_50)
print("AP_75: ", AP_75)
print("mAP: ", mAP)
# Out:
# Processing img. 1  : left_Explorer_HD720_SN15385_04-00-39.png
# 0.3415378018973021
# Processing img. 2  : left_Explorer_HD720_SN15385_05-00-63.png
# Processing img. 3  : left_Explorer_HD720_SN15385_05-00-52.png
# 0.1657555690608267
# Processing img. 4  : left_Explorer_HD720_SN15385_04-00-43.png
# 0.35070053836441634
# Processing img. 5  : left_Explorer_HD720_SN15385_03-00-28.png
# Processing img. 6  : left_Explorer_HD720_SN15385_19-31-08.png
# Processing img. 7  : left_Explorer_HD720_SN15385_04-00-58.png
# 0.2510406259318808
# Processing img. 8  : left_Explorer_HD720_SN15385_04-00-67.png
# 0.4746307292658009
# Processing img. 9  : left_Explorer_HD720_SN15385_03-00-39.png
# Processing img. 10  : left_Explorer_HD720_SN15385_04-00-16.png
# Processing img. 11  : left_Explorer_HD720_SN15385_04-00-89.png
# Processing img. 12  : left_Explorer_HD720_SN15385_19-31-10.png
# Processing img. 13  : left_Explorer_HD720_SN15385_03-00-25.png
# 0.15139033955171957
# Processing img. 14  : left_Explorer_HD720_SN15385_03-00-05.png
# Processing img. 15  : left_Explorer_HD720_SN15385_03-00-61.png
# Processing img. 16  : left_Explorer_HD720_SN15385_05-00-62.png
# Processing img. 17  : left_Explorer_HD720_SN15385_03-00-29.png
# 0.2500199876242347
# Processing img. 18  : left_Explorer_HD720_SN15385_05-00-27.png
# Processing img. 19  : left_Explorer_HD720_SN15385_04-00-06.png
# Processing img. 20  : left_Explorer_HD720_SN15385_05-00-25.png
# Processing img. 21  : left_Explorer_HD720_SN15385_03-00-22.png
# 0.4598406932052052
# 0.37150731926486147
# Processing img. 22  : left_Explorer_HD720_SN15385_03-00-30.png
# 0.49942599893110484
# Processing img. 23  : left_Explorer_HD720_SN15385_19-32-06.png
# 0.39729926751180733
# Processing img. 24  : left_Explorer_HD720_SN15385_03-00-36.png
# Processing img. 25  : left_Explorer_HD720_SN15385_03-00-31.png
# Processing img. 26  : left_Explorer_HD720_SN15385_05-00-34.png
# Processing img. 27  : left_Explorer_HD720_SN15385_19-32-20.png
# Processing img. 28  : left_Explorer_HD720_SN15385_19-30-48.png
# Processing img. 29  : left_Explorer_HD720_SN15385_04-00-47.png
# Processing img. 30  : left_Explorer_HD720_SN15385_03-00-17.png
# Processing img. 31  : left_Explorer_HD720_SN15385_04-00-18.png
# 0.3981046439992836
# Processing img. 32  : left_Explorer_HD720_SN15385_05-00-35.png
# Processing img. 33  : left_Explorer_HD720_SN15385_19-31-34.png
# Processing img. 34  : left_Explorer_HD720_SN15385_05-00-33.png
# Processing img. 35  : left_Explorer_HD720_SN15385_04-00-71.png
# 0.14958401416746872
# Processing img. 36  : left_Explorer_HD720_SN15385_05-00-82.png
# Processing img. 37  : left_Explorer_HD720_SN15385_04-00-59.png
# 0.05448627036254491
# 0.2597322933716982
# Processing img. 38  : left_Explorer_HD720_SN15385_05-00-58.png
# Processing img. 39  : left_Explorer_HD720_SN15385_05-00-16.png
# Processing img. 40  : left_Explorer_HD720_SN15385_04-00-75.png
# 0.19079114598976152
# Processing img. 41  : left_Explorer_HD720_SN15385_05-00-07.png
# Processing img. 42  : left_Explorer_HD720_SN15385_05-00-47.png
# Processing img. 43  : left_Explorer_HD720_SN15385_03-00-24.png
# Processing img. 44  : left_Explorer_HD720_SN15385_04-00-82.png
# Processing img. 45  : left_Explorer_HD720_SN15385_19-30-29.png
# Processing img. 46  : left_Explorer_HD720_SN15385_03-00-34.png
# Processing img. 47  : left_Explorer_HD720_SN15385_03-00-62.png
# Processing img. 48  : left_Explorer_HD720_SN15385_04-00-33.png
# 0.22838532639239637
# Processing img. 49  : left_Explorer_HD720_SN15385_04-00-90.png
# Processing img. 50  : left_Explorer_HD720_SN15385_19-31-20.png
# Processing img. 51  : left_Explorer_HD720_SN15385_04-00-04.png
# Processing img. 52  : left_Explorer_HD720_SN15385_03-00-35.png
# Processing img. 53  : left_Explorer_HD720_SN15385_03-00-70.png
# 0.3648476929856702
# Processing img. 54  : left_Explorer_HD720_SN15385_05-00-04.png
# Processing img. 55  : left_Explorer_HD720_SN15385_19-30-08.png
# Processing img. 56  : left_Explorer_HD720_SN15385_04-00-32.png
# Processing img. 57  : left_Explorer_HD720_SN15385_05-00-02.png
# Processing img. 58  : left_Explorer_HD720_SN15385_03-00-65.png
# 0.4241850334427824
# Processing img. 59  : left_Explorer_HD720_SN15385_05-00-19.png
# Processing img. 60  : left_Explorer_HD720_SN15385_19-30-22.png
# Processing img. 61  : left_Explorer_HD720_SN15385_19-32-52.png
# Processing img. 62  : left_Explorer_HD720_SN15385_05-00-09.png
# Processing img. 63  : left_Explorer_HD720_SN15385_19-30-34.png
# Processing img. 64  : left_Explorer_HD720_SN15385_05-00-17.png
# Processing img. 65  : left_Explorer_HD720_SN15385_05-00-28.png
# Processing img. 66  : left_Explorer_HD720_SN15385_19-34-41.png
# AP_50:  0.8972972972972973
# AP_75:  0.6378378378378379
# mAP:  [0.59783784]

# %%
AP_50, AP_75, mAP = evaluate_model("./results_full/mobilenet_model_COCO_368x765//NMS_v2/record.json", './self_dataset/labelme/gt_json_train/')

print("AP_50: ", AP_50)
print("AP_75: ", AP_75)
print("mAP: ", mAP)
# Out:
# Processing img. 1  : left_Explorer_HD720_SN15385_04-00-39.png
# 0.19833599578051928
# Processing img. 2  : left_Explorer_HD720_SN15385_05-00-63.png
# Processing img. 3  : left_Explorer_HD720_SN15385_05-00-52.png
# 0.14339687150970462
# Processing img. 4  : left_Explorer_HD720_SN15385_04-00-43.png
# 0.1684127838084165
# Processing img. 5  : left_Explorer_HD720_SN15385_03-00-28.png
# 0.27877264401524143
# Processing img. 6  : left_Explorer_HD720_SN15385_19-31-08.png
# Processing img. 7  : left_Explorer_HD720_SN15385_04-00-58.png
# 0.12512186799332567
# Processing img. 8  : left_Explorer_HD720_SN15385_04-00-67.png
# Processing img. 9  : left_Explorer_HD720_SN15385_03-00-39.png
# Processing img. 10  : left_Explorer_HD720_SN15385_04-00-16.png
# 0.37449966257484446
# Processing img. 11  : left_Explorer_HD720_SN15385_04-00-89.png
# Processing img. 12  : left_Explorer_HD720_SN15385_19-31-10.png
# Processing img. 13  : left_Explorer_HD720_SN15385_03-00-25.png
# 0.267492050287332
# Processing img. 14  : left_Explorer_HD720_SN15385_03-00-05.png
# Processing img. 15  : left_Explorer_HD720_SN15385_03-00-61.png
# Processing img. 16  : left_Explorer_HD720_SN15385_05-00-62.png
# Processing img. 17  : left_Explorer_HD720_SN15385_03-00-29.png
# 0.10108473721374574
# Processing img. 18  : left_Explorer_HD720_SN15385_05-00-27.png
# 0.18455545933956127
# Processing img. 19  : left_Explorer_HD720_SN15385_04-00-06.png
# 0.41085733646101535
# Processing img. 20  : left_Explorer_HD720_SN15385_05-00-25.png
# Processing img. 21  : left_Explorer_HD720_SN15385_03-00-22.png
# 0.4692283778615211
# 0.46255908802275497
# Processing img. 22  : left_Explorer_HD720_SN15385_03-00-30.png
# 0.22614185877127352
# Processing img. 23  : left_Explorer_HD720_SN15385_19-32-06.png
# 0.38035181553246245
# 0.35393507395325524
# Processing img. 24  : left_Explorer_HD720_SN15385_03-00-36.png
# Processing img. 25  : left_Explorer_HD720_SN15385_03-00-31.png
# Processing img. 26  : left_Explorer_HD720_SN15385_05-00-34.png
# Processing img. 27  : left_Explorer_HD720_SN15385_19-32-20.png
# 0.4982889349920053
# Processing img. 28  : left_Explorer_HD720_SN15385_19-30-48.png
# Processing img. 29  : left_Explorer_HD720_SN15385_04-00-47.png
# Processing img. 30  : left_Explorer_HD720_SN15385_03-00-17.png
# Processing img. 31  : left_Explorer_HD720_SN15385_04-00-18.png
# 0.3061019875631977
# 0.4221872986380122
# Processing img. 32  : left_Explorer_HD720_SN15385_05-00-35.png
# Processing img. 33  : left_Explorer_HD720_SN15385_19-31-34.png
# Processing img. 34  : left_Explorer_HD720_SN15385_05-00-33.png
# 0.4543449071084117
# Processing img. 35  : left_Explorer_HD720_SN15385_04-00-71.png
# 0.4224178885761314
# 0.19641004993739725
# Processing img. 36  : left_Explorer_HD720_SN15385_05-00-82.png
# Processing img. 37  : left_Explorer_HD720_SN15385_04-00-59.png
# 0.09190003405602148
# 0.2681591039960828
# Processing img. 38  : left_Explorer_HD720_SN15385_05-00-58.png
# Processing img. 39  : left_Explorer_HD720_SN15385_05-00-16.png
# Processing img. 40  : left_Explorer_HD720_SN15385_04-00-75.png
# 0.09680300295748046
# Processing img. 41  : left_Explorer_HD720_SN15385_05-00-07.png
# 0.4738291776425452
# Processing img. 42  : left_Explorer_HD720_SN15385_05-00-47.png
# Processing img. 43  : left_Explorer_HD720_SN15385_03-00-24.png
# Processing img. 44  : left_Explorer_HD720_SN15385_04-00-82.png
# Processing img. 45  : left_Explorer_HD720_SN15385_19-30-29.png
# 0.1886019001295983
# Processing img. 46  : left_Explorer_HD720_SN15385_03-00-34.png
# Processing img. 47  : left_Explorer_HD720_SN15385_03-00-62.png
# Processing img. 48  : left_Explorer_HD720_SN15385_04-00-33.png
# 0.37789084543325346
# Processing img. 49  : left_Explorer_HD720_SN15385_04-00-90.png
# Processing img. 50  : left_Explorer_HD720_SN15385_19-31-20.png
# 0.2642471890845174
# Processing img. 51  : left_Explorer_HD720_SN15385_04-00-04.png
# Processing img. 52  : left_Explorer_HD720_SN15385_03-00-35.png
# Processing img. 53  : left_Explorer_HD720_SN15385_03-00-70.png
# 0.3277562418436406
# 0.4075340202929536
# Processing img. 54  : left_Explorer_HD720_SN15385_05-00-04.png
# Processing img. 55  : left_Explorer_HD720_SN15385_19-30-08.png
# Processing img. 56  : left_Explorer_HD720_SN15385_04-00-32.png
# Processing img. 57  : left_Explorer_HD720_SN15385_05-00-02.png
# Processing img. 58  : left_Explorer_HD720_SN15385_03-00-65.png
# 0.35099232916960416
# Processing img. 59  : left_Explorer_HD720_SN15385_05-00-19.png
# Processing img. 60  : left_Explorer_HD720_SN15385_19-30-22.png
# Processing img. 61  : left_Explorer_HD720_SN15385_19-32-52.png
# Processing img. 62  : left_Explorer_HD720_SN15385_05-00-09.png
# Processing img. 63  : left_Explorer_HD720_SN15385_19-30-34.png
# Processing img. 64  : left_Explorer_HD720_SN15385_05-00-17.png
# Processing img. 65  : left_Explorer_HD720_SN15385_05-00-28.png
# Processing img. 66  : left_Explorer_HD720_SN15385_19-34-41.png
# AP_50:  0.8324324324324325
# AP_75:  0.4810810810810811
# mAP:  [0.47189189]
