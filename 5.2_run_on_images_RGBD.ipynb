# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import cv2
import utils_library.visualization.visualizations as vis
from applications.model_wrapper import ModelWrapper
import utils_library.post_processing.post as post
import utils_library.configs.draw_config as draw_config
import utils_library.configs.post_config as post_config
import utils_library.configs.keypoints_config as kpts_config
import utils_library.configs.default_config as def_config
post.Skeletonizer.config(kpts_config.KEYPOINTS_DEF, kpts_config.JOINTS_DEF, post_config)
post.Skeleton.config(kpts_config.KEYPOINTS_DEF, kpts_config.JOINTS_DEF)
import time


def preprocess_img(img):
    """
    This function implements the preprocessing of input image.
    Input original img, it will:
    1. add newaxis to first dimension
    2. fix image height to 368 and proportionally resize image width
    """
    inHeight = img.shape[0]
    inWidth = img.shape[1]
    frameHeight = 368
    frameWidth = round(frameHeight/inHeight * inWidth)

    input_img = tf.image.resize(img, (frameHeight, frameWidth))
    input_img = tf.image.convert_image_dtype(input_img, dtype=tf.float32)

    input_img = input_img[tf.newaxis, ...]

    return input_img


def process_image(img_path):
    # load images and do preprocessing
    img_rgbd = plt.imread(img_path)
    img_rgb = (img_rgbd[...,:3]*255).astype('uint8')
    input_img = preprocess_img(img_rgbd)

    # predict and post-processing
    start_time = time.time()
    pafs, kpts = model.predict(input_img)
    end_time = time.time()
    model_time = end_time - start_time

    start_time = time.time()
    skeletonizer = post.Skeletonizer(kpts[0], pafs[0])
    skeletons = skeletonizer.create_skeletons()
    end_time = time.time()
    post_time = end_time - start_time

    skeleton_drawer = vis.SkeletonDrawer(img_rgb, draw_config)
    for skeleton in skeletons:
        skeleton.draw_skeleton(skeleton_drawer.joint_draw, skeleton_drawer.kpt_draw)

    return skeletons, img_rgb, model_time, post_time

# %%
## configs
#model_path = "./trained_models/model11_test-15Sun1219-2101/"
model_name = "COCO+RGBD_concat"
model_path = "./trained_models/RGBD_models/" + model_name
img_dir = "./self_dataset/RGBD_Dataset/RGBD_imgs/"

# loading model and check architecture
model = tf.keras.models.load_model(model_path)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
# creating json file
RESULT_ROOT = './results/RGBD_results/'
result_dir = RESULT_ROOT + model_name + '/NMS_v2/'
result_json_file = result_dir + 'record.json'
result_imgs = result_dir + 'images/'

import os
if not os.path.isdir(result_dir):
    os.makedirs(result_dir, )
if not os.path.isdir(result_imgs):
    os.mkdir(result_imgs)

import json
result_dict = {}
img_num = 0
model_t_sum = 0
post_t_sum = 0

for line in open("./self_dataset/imgL.txt"):
    img_num += 1
    img_name = line[-41:-1]
    print(img_num, "/65 :", img_name)
    img_path = img_dir + img_name
    
    skeletons, img_rgb, model_time, post_time = process_image(img_path)
    
    model_t_sum += model_time
    post_t_sum += post_time
    
    temp = {}
    n = 1
    for skeleton in skeletons:
        person_name = "person" + str(n)
        temp[person_name] = {}
        for name in skeleton.keypoints:
            temp[person_name][name] = [skeleton.keypoints[name][0] * img_rgb.shape[0],
                                              skeleton.keypoints[name][1] * img_rgb.shape[1]]
        n += 1
    
    result_dict[img_name] = temp
    plt.imsave(result_imgs+img_name, img_rgb)
    print("Average model time usage: ", model_t_sum/img_num)
    print("Average post time usage: ", post_t_sum/img_num)

result_json = json.dumps(result_dict)
with open(result_json_file,"w") as f:
    json.dump(result_json,f)
# Out:
# 1 /65 : left_Explorer_HD720_SN15385_19-30-08.png
# Average model time usage:  3.336137056350708
# Average post time usage:  0.025400161743164062
# 2 /65 : left_Explorer_HD720_SN15385_19-33-55.png
# Average model time usage:  1.9885574579238892
# Average post time usage:  0.03142058849334717
# 3 /65 : left_Explorer_HD720_SN15385_19-34-28.png
# Average model time usage:  1.5128939946492512
# Average post time usage:  0.027468760808308918
# 4 /65 : left_Explorer_HD720_SN15385_19-34-00.png
# Average model time usage:  1.2741947770118713
# Average post time usage:  0.02494335174560547
# 5 /65 : left_Explorer_HD720_SN15385_19-34-31.png
# Average model time usage:  1.1284853935241699
# Average post time usage:  0.02453446388244629
# 6 /65 : left_Explorer_HD720_SN15385_19-31-10.png
# Average model time usage:  1.0337401628494263
# Average post time usage:  0.023979385693868
# 7 /65 : left_Explorer_HD720_SN15385_19-31-36.png
# Average model time usage:  0.9747438430786133
# Average post time usage:  0.023616041455950056
# 8 /65 : left_Explorer_HD720_SN15385_19-30-29.png
# Average model time usage:  0.9206017255783081
# Average post time usage:  0.022986799478530884
# 9 /65 : left_Explorer_HD720_SN15385_19-31-25.png
# Average model time usage:  0.8795518345303006
# Average post time usage:  0.022457811567518447
# 10 /65 : left_Explorer_HD720_SN15385_19-33-07.png
# Average model time usage:  0.847612452507019
# Average post time usage:  0.022262430191040038
# 11 /65 : left_Explorer_HD720_SN15385_19-31-44.png
# Average model time usage:  0.821670575575395
# Average post time usage:  0.022296211936257103
# 12 /65 : left_Explorer_HD720_SN15385_19-34-37.png
# Average model time usage:  0.8010486165682474
# Average post time usage:  0.0223080317179362
# 13 /65 : left_Explorer_HD720_SN15385_19-36-25.png
# Average model time usage:  0.7830020280984732
# Average post time usage:  0.022718429565429688
# 14 /65 : left_Explorer_HD720_SN15385_19-33-57.png
# Average model time usage:  0.7685027463095528
# Average post time usage:  0.02250323976789202
# 15 /65 : left_Explorer_HD720_SN15385_19-34-18.png
# Average model time usage:  0.7542742411295573
# Average post time usage:  0.022257010142008465
# 16 /65 : left_Explorer_HD720_SN15385_19-35-48.png
# Average model time usage:  0.7427629232406616
# Average post time usage:  0.022816568613052368
# 17 /65 : left_Explorer_HD720_SN15385_19-36-44.png
# Average model time usage:  0.733069518033196
# Average post time usage:  0.023470542010139015
# 18 /65 : left_Explorer_HD720_SN15385_19-29-59.png
# Average model time usage:  0.7250378794140286
# Average post time usage:  0.02343173821767171
# 19 /65 : left_Explorer_HD720_SN15385_19-33-02.png
# Average model time usage:  0.7174838969582006
# Average post time usage:  0.023371646278782895
# 20 /65 : left_Explorer_HD720_SN15385_19-35-37.png
# Average model time usage:  0.7103635549545289
# Average post time usage:  0.023492062091827394
# 21 /65 : left_Explorer_HD720_SN15385_19-30-48.png
# Average model time usage:  0.7040860993521554
# Average post time usage:  0.023390576952979678
